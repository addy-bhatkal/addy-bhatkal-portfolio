# %%
import pandas as pd, numpy as np, psutil, os
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import TruncatedSVD

# %%
pwd
# Out:
# '/Users/adityabhatkal/Desktop/Changes addy-bhatkal-portfolio _ being made'

# %%
os.listdir()
os.chdir('/Users/adityabhatkal/Desktop/Practice 31 - The App')

# %%
df = pd.read_csv('spotify_millsongdata2.csv')

# %%
df
# Out:
#        Unnamed: 0        artist                   song  \
# 0               0          ABBA  Ahe's My Kind Of Girl
# 1               1          ABBA       Andante, Andante
# 2               2          ABBA         As Good As New
# 3               3          ABBA                   Bang
# 4               4          ABBA       Bang-A-Boomerang
# ...           ...           ...                    ...
# 57645       57645  Ziggy Marley          Good Old Days
# 57646       57646  Ziggy Marley          Hand To Mouth
# 57647       57647          Zwan           Come With Me
# 57648       57648          Zwan                 Desire
# 57649       57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text  \
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...
#
#                       song_artist
# 0      Ahe's My Kind Of Girl-ABBA
# 1           Andante, Andante-ABBA
# 2             As Good As New-ABBA
# 3                       Bang-ABBA
# 4           Bang-A-Boomerang-ABBA
# ...                           ...
# 57645  Good Old Days-Ziggy Marley
# 57646  Hand To Mouth-Ziggy Marley
# 57647           Come With Me-Zwan
# 57648                 Desire-Zwan
# 57649              Heartsong-Zwan
#
# [57650 rows x 6 columns]

# %%
df['song_artist'] = df['song'] + "-" + df['artist']
df
# Out:
#        Unnamed: 0        artist                   song  \
# 0               0          ABBA  Ahe's My Kind Of Girl
# 1               1          ABBA       Andante, Andante
# 2               2          ABBA         As Good As New
# 3               3          ABBA                   Bang
# 4               4          ABBA       Bang-A-Boomerang
# ...           ...           ...                    ...
# 57645       57645  Ziggy Marley          Good Old Days
# 57646       57646  Ziggy Marley          Hand To Mouth
# 57647       57647          Zwan           Come With Me
# 57648       57648          Zwan                 Desire
# 57649       57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text  \
# 0      Look at her face, it's a wonderful face  \r\nA...
# 1      Take it easy with me, please  \r\nTouch me gen...
# 2      I'll never know why I had to go  \r\nWhy I had...
# 3      Making somebody happy is a question of give an...
# 4      Making somebody happy is a question of give an...
# ...                                                  ...
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...
#
#                       song_artist
# 0      Ahe's My Kind Of Girl-ABBA
# 1           Andante, Andante-ABBA
# 2             As Good As New-ABBA
# 3                       Bang-ABBA
# 4           Bang-A-Boomerang-ABBA
# ...                           ...
# 57645  Good Old Days-Ziggy Marley
# 57646  Hand To Mouth-Ziggy Marley
# 57647           Come With Me-Zwan
# 57648                 Desire-Zwan
# 57649              Heartsong-Zwan
#
# [57650 rows x 6 columns]

# %%
#df.to_csv('spotify_millsongdata2.csv', index=True)

# %%
pwd
# Out:
# '/Users/adityabhatkal/Desktop/Practice 31 - The App'

# %%
tf = TfidfVectorizer(ngram_range=(1,2), max_df=0.5, min_df=5, stop_words='english')
listy = []
def reco():
    song = input("insert song name: ")
    vec = tf.fit_transform(df['text'])
    lsa = TruncatedSVD(n_components=100)  # Choose number of dimensions to reduce to
    lsa_matrix = lsa.fit_transform(vec)
    val1 = tf.transform([song])
    val2 = lsa.transform(val1)
    sim = cosine_similarity(lsa_matrix, val2)
    listy = []
    distances = sorted(list(enumerate(sim)), reverse= True, key = lambda x : x[1])
    for i in distances[:20]:
        listy.append([df.iloc[i[0]][1], df.iloc[i[0]][2]])
        listy2 = pd.DataFrame(listy)
    print(listy2)

# %%
reco()
# Out:
#                         0                             1
# 0         Doobie Brothers                  Cotton Mouth
# 1              Carpenters                          Sing
# 2            Indigo Girls                          Damo
# 3             The Beatles                         Julia
# 4      Dave Matthews Band                    Sing Along
# 5               Ray Boltz              My Father's Song
# 6                 Sublime             Rivers Of Babylon
# 7          Paul McCartney              I Am Your Singer
# 8              Peter Tosh                    In My Song
# 9           Cliff Richard               From A Distance
# 10         Point Of Grace                   All Is Well
# 11           Donna Summer                    Sing Along
# 12  Indiana Bible College                   Glorify Him
# 13           Dolly Parton                     Applejack
# 14       Michael W. Smith                   All Is Well
# 15                 Oliver        Good Morning Starshine
# 16              Amy Grant  Sing Your Praise To The Lord
# 17              Kari Jobe                      Joyfully
# 18            Matt Redman                     Thank You
# 19                 Travis                          Sing
# /var/folders/5b/x781v7v10sbdq6q4d2sf3myc0000gn/T/ipykernel_78531/508343644.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   listy.append([df.iloc[i[0]][1], df.iloc[i[0]][2]])

# %%
FutureWarning: Series.__getitem__ treating keys as positions is deprecated. 
In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). 
To access a value by position, use `ser.iloc[pos]`
  listy.append([df.iloc[i[0]][0], df.iloc[i[0]][1]])
# Out:
#   Cell In[11], line 1
#     FutureWarning: Series.__getitem__ treating keys as positions is deprecated.
#                                       ^
# SyntaxError: invalid syntax
